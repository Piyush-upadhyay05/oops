# %% [markdown]
# ### Data type
#
# - defines memory storage
#
# - defines allowed operations
#
# ##### - There are two types of data types :
#
#    - 1. user defined data type
#
#      - you can create your own data type containing your own value and function
#      - example - class , structure , union
#
#    - 2. built in data types

# %% [markdown]
# ### Absract data type
#
# - ADT are like user defined data types and which defines operations on values using functions without specifying what is there inside a function and how opoerations are performed

# %% [markdown]
# # 📘 Common Abstract Data Types (ADTs)
#
# Below are commonly used **Abstract Data Types (ADTs)** with simple explanations and real-life analogies.
#
# ---
#
# ## 🔶 ADT Examples Table
#
# | ADT          | Real-Life Analogy                   | Description                          |
# |--------------|-------------------------------------|--------------------------------------|
# | **Stack**    | Plates stacked in a canteen         | Last in, first out (LIFO)            |
# | **Queue**    | People in line at a ticket counter  | First in, first out (FIFO)           |
# | **Deque**    | Train with two open doors           | Insert/delete from both ends         |
# | **List**     | Shopping list                       | Ordered collection of items          |
# | **Set**      | Bag of unique stones                | Unordered collection of unique items |
# | **Map**      | Phonebook: Name → Phone number      | Stores key-value pairs               |
# | **Graph**    | Metro map, Social network           | Nodes connected by edges             |
# | **Tree**     | Family tree, File system            | Hierarchical parent-child structure  |
# | **Priority Queue** | Hospital emergency room        | Based on element priority            |
# | **Hash Table** | Locker with number keys           | Fast lookup using keys               |
#
# ---
#
# ## 🧠 Short Descriptions with Use Cases
#
# ### 1. **Stack (LIFO)**
# - **Operations**: Push, Pop, Peek
# - **Use Cases**: Undo feature, Function calls, Expression evaluation
#
# ### 2. **Queue (FIFO)**
# - **Operations**: Enqueue, Dequeue, Front
# - **Use Cases**: Task scheduling, Printer queues, BFS
#
# ### 3. **Deque (Double-Ended Queue)**
# - **Operations**: Add/remove from both ends
# - **Use Cases**: Sliding window problems, Palindrome checking
#
# ### 4. **List / Array / Linked List**
# - **Operations**: Insert, Delete, Search
# - **Use Cases**: General data storage, Navigation
#
# ### 5. **Set**
# - **Operations**: Add, Remove, Membership test
# - **Use Cases**: Removing duplicates, Set operations
#
# ### 6. **Map / Dictionary**
# - **Operations**: Add key-value, Search by key
# - **Use Cases**: Caching, Student marks database
#
# ### 7. **Tree (Binary Tree, BST, etc.)**
# - **Operations**: Insert, Delete, Traverse
# - **Use Cases**: Hierarchical data, Search systems
#
# ### 8. **Graph**
# - **Operations**: Add edge, Remove edge, Traverse
# - **Use Cases**: Social networks, Maps, Web crawling
#
# ### 9. **Priority Queue / Heap**
# - **Operations**: Insert, Remove highest/lowest priority
# - **Use Cases**: Dijkstra’s algorithm, CPU scheduling
#
# ---
#
# ## ✅ ADT Comparison Table
#
# | ADT Name         | Ordered? | Duplicates Allowed? | Key Feature             |
# |------------------|----------|---------------------|-------------------------|
# | Stack            | Yes      | Yes                 | LIFO                    |
# | Queue            | Yes      | Yes                 | FIFO                    |
# | Deque            | Yes      | Yes                 | Double-ended            |
# | List             | Yes      | Yes                 | Index-based access      |
# | Set              | No       | No                  | Unique elements only    |
# | Map / Dictionary | N/A      | Unique keys         | Key-value storage       |
# | Tree             | Yes      | Depends             | Hierarchical structure  |
# | Graph            | No       | Depends             | Node-edge based         |
# | Priority Queue   | Yes      | Yes                 | Based on priority       |
#
# ---
#
# *Created by Piyush Upadhyay – Learn and grow with Python and Data Structures! 🌱*
