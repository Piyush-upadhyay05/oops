# %% [markdown]
# # 1.  Basic OOP Concepts
# Class and Object
#
# __init__ Method (Constructor)
#
# Instance Variables
#
# Instance Methods
#
# Class Variables
#
# Class Methods
#
# Static Methods
#
# # 2. Encapsulation
# Public, Protected, and Private Members
#
# Getter and Setter Methods
#
# Property Decorator (@property)
#
# # 3. Inheritance
# Single Inheritance
#
# Multilevel Inheritance
#
# Hierarchical Inheritance
#
# Multiple Inheritance
#
# super() Function
#
# # 4. Polymorphism
# Method Overriding
#
# Method Overloading (via default arguments)
#
# Operator Overloading
#
# Duck Typing
#
# # 5.  Abstraction
# Abstract Classes
#
# Abstract Methods
#
# abc Module
#
# # 6.  Special (Magic/Dunder) Methods
# __str__ and __repr__
#
# __add__, __sub__, etc. (Operator Overloading)
#
# __len__, __getitem__, __setitem__
#
# __eq__, __lt__, etc. (Comparison Overloading)
#
# # 7. Advanced OOP Concepts
# Object Introspection (type(), id(), dir(), hasattr(), getattr(), etc.)
#
# Composition vs Inheritance
#
# Aggregation
#
# MRO (Method Resolution Order)
#
# Metaclasses
#
# Data Classes (@dataclass)
#
# Slots (__slots__)
